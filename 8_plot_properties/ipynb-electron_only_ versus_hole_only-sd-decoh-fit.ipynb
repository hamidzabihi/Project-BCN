# %%
import os
import sys
import math
import time
import glob 

import multiprocessing as mp
import numpy as np
import scipy.sparse as sp
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
# %matplotlib inline

from liblibra_core import *
import util.libutil as comn
from libra_py import units as units
from libra_py import data_conv, data_stat, data_outs, data_read
import libra_py.workflows.nbra.decoherence_times as decoherence_times
import libra_py.workflows.nbra.step4 as step4
import libra_py.workflows.nbra.ann as ann
# Out:
# /home/98722002/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)

# %% [markdown]
# ## average_decoherence_hole_only_sd

# %%
# %matplotlib inline
#notebook
figure = plt.figure(num=None, figsize=(2.41, 2.41), dpi=300, edgecolor='black', frameon=True)        

avg_deco = np.loadtxt('./results/average_decoherence_hole_only_sd.txt')
plt.imshow(np.flipud(avg_deco), extent=(0,avg_deco.shape[0],0,avg_deco.shape[1]), cmap='hot')
plt.colorbar().ax.set_title('fs')
plt.title('BCN')
plt.xlabel('State_index')
plt.ylabel('State index')
plt.savefig('./results/average_decoherence_hole_only_sd.png', dpi=600)

# %% [markdown]
# ## average_decoherence_electron_only_sd

# %%
# %matplotlib inline
#notebook
figure = plt.figure(num=None, figsize=(2.41, 2.41), dpi=300, edgecolor='black', frameon=True)        

avg_deco = np.loadtxt('./results/average_decoherence_electron_only_sd.txt')
plt.imshow(np.flipud(avg_deco), extent=(0,avg_deco.shape[0],0,avg_deco.shape[1]), cmap='hot')
plt.colorbar().ax.set_title('fs')
plt.title('BCN')
plt.xlabel('State_index')
plt.ylabel('State index')
plt.savefig('./results/average_decoherence_electron_only_sd.png', dpi=600)

# %%
# %matplotlib inline
#notebook
#figure = plt.figure(num=None, figsize=(3.21, 2.41), dpi=300, edgecolor='black', frameon=True)        

def stretched_compressed(t, tau, beta):
    return np.exp( -np.power(( t/tau ),beta) )

for c, scheme in enumerate(['FSSH', 'IDA','mSDM']):
    figure = plt.figure(num=None, figsize=(3.21, 2.41), dpi=600, edgecolor='black', frameon=True)
    print(F'------------{scheme}----------')
    #plt.subplot(1,2,c+1)
    folders = glob.glob(F'./results/namd_regular_hole_only_sd/_start_s10_{scheme}_batch*', recursive = True)
    taus = []
    betas = []
    
    for folder in folders:
        
        print("Folder =", folder)
        sh_pop = np.loadtxt(folder+'/SH_pop.txt')
        sh_pop_hot_state = sh_pop[:,10]
        md_time = np.arange(0, sh_pop_hot_state.shape[0], 1.0)
        popt, pcov = curve_fit( stretched_compressed, md_time, sh_pop_hot_state, 
                                   bounds=([0.0, 0.0],[np.inf, np.inf]))
        tau, beta = popt
        # Computing the R-squared
        residuals  = sh_pop_hot_state - stretched_compressed(md_time, *popt)
        ss_res     = np.sum(residuals**2)
        ss_tot     = np.sum((sh_pop_hot_state - np.mean(sh_pop_hot_state))**2)
        r_squared  = 1.0 - (ss_res / ss_tot)
        print('tau:', tau, ' beta:', beta,' R2:', r_squared)
        
        if r_squared>0.01:
            taus.append(tau)
            betas.append(beta)
            plt.plot(md_time, sh_pop_hot_state,  linewidth=1, color = "mediumorchid")
            
    ave_tau = np.average(np.array(taus))
    ave_beta = np.average(np.array(betas))
    # Compute the erro bars
    # The confidence interval
    Z = 1.96
    N = len(taus)
    s = np.std(np.array(taus))
    error_bar = Z*s/np.sqrt(N)
    
######################################################################################################################        
    
    
    folders2 = glob.glob(F'./results//namd_regular_electron_only_sd/_start_s10_{scheme}_batch*', recursive = True)
    taus2 = []
    betas2 = []    
    for folder in folders2:
        
        print("Folder =", folder)
        sh_pop = np.loadtxt(folder+'/SH_pop.txt')
        sh_pop_hot_state = sh_pop[:,10]
        md_time2 = np.arange(0, sh_pop_hot_state.shape[0], 1.0)
        popt, pcov = curve_fit( stretched_compressed, md_time, sh_pop_hot_state, 
                                   bounds=([0.0, 0.0],[np.inf, np.inf]))
        tau, beta = popt
        # Computing the R-squared
        residuals  = sh_pop_hot_state - stretched_compressed(md_time, *popt)
        ss_res     = np.sum(residuals**2)
        ss_tot     = np.sum((sh_pop_hot_state - np.mean(sh_pop_hot_state))**2)
        r_squared  = 1.0 - (ss_res / ss_tot)
        print('tau:', tau, ' beta:', beta,' R2:', r_squared)
        
        if r_squared>0.01:
            taus2.append(tau)
            betas2.append(beta)
            plt.plot(md_time2, sh_pop_hot_state,  linewidth=1, color = "mediumseagreen")
            
    ave_tau2 = np.average(np.array(taus2))
    ave_beta2 = np.average(np.array(betas2))
    # Compute the erro bars
    # The confidence interval
    Z = 1.96
    N = len(taus2)
    s = np.std(np.array(taus2))
    error_bar = Z*s/np.sqrt(N)
    
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@2    
    
    print(F'The timescales: {ave_tau}+-{error_bar} average over {len(taus)} samples')
    # Plot average fit
    #plt.plot(md_time, stretched_compressed(md_time, ave_tau-error_bar, ave_beta), ls='--',linewidth=3, color='red')
    plt.plot(md_time, stretched_compressed(md_time, ave_tau,           ave_beta), ls='-',  linewidth=3,label='$h^+$', color='rebeccapurple')
    plt.plot(md_time2, stretched_compressed(md_time2, ave_tau2,           ave_beta2), ls='-',  linewidth=3,label='$e^-$', color='darkcyan')

    #plt.plot(md_time, stretched_compressed(md_time, ave_tau+error_bar, ave_beta), ls='--', linewidth=3, color='red')
        
    plt.legend(fontsize=6, ncol=1, loc='upper right')
    plt.title(scheme)
    plt.xlabel('Time, fs')
    plt.ylabel('Population')
    plt.tight_layout()
    plt.savefig(F'./results/{scheme}electron_hole_only.png', dpi=600)
    plt.show()
# Out:
# ------------FSSH----------
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch1
# tau: 89.95066933186942  beta: 1.8746978844005945e-11  R2: -4102.4988953013935
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch2
# tau: 89.95066933186942  beta: 1.8746978844005945e-11  R2: -4102.4988953013935
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch0
# tau: 89.95066933186942  beta: 1.8746978844005945e-11  R2: -4102.4988953013935
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch6
# tau: 89.95069301738883  beta: 2.250276361004177e-11  R2: -2454.639034586367
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch7
# tau: 89.95066450595287  beta: 1.8080616760204313e-11  R2: -5828.593568462278
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch5
# tau: 89.95075100328928  beta: 3.412727962486868e-11  R2: -705.4746769642769
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch9
# tau: 89.95075100328928  beta: 3.412727962486868e-11  R2: -705.4746769642769
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch3
# tau: 89.95069552793512  beta: 2.2986075004504547e-11  R2: -1530.2417169876082
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch4
# tau: 89.95069552793512  beta: 2.2986075004504547e-11  R2: -1530.2417169876082
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch14
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in double_scalars
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch8
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch13
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch10
# tau: 89.95066318880927  beta: 1.7908882560213298e-11  R2: -6715.344439505553
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch15
# tau: 89.95066318880927  beta: 1.7908882560213298e-11  R2: -6715.344439505553
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch11
# tau: 89.95066318880927  beta: 1.7908882560213298e-11  R2: -6715.344439505553
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch12
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch16
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch17
# tau: 89.95066214492934  beta: 1.777600094582011e-11  R2: -7714.181548247385
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch19
# tau: 89.95069725840683  beta: 2.318844797396101e-11  R2: -2467.779393345563
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_FSSH_batch18
# tau: 89.95069725840683  beta: 2.318844797396101e-11  R2: -2467.779393345563
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch0
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:195: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# tau: 180.4606093632998  beta: 3.4489269791004347e-20  R2: -45.26024977029707
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch3
# tau: 180.46114562088655  beta: 1.660925523652123e-17  R2: -8.410348585427533
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch4
# tau: 180.46092771759714  beta: 6.965590744587071e-19  R2: -13.880682002787893
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch2
# tau: 180.46123698915662  beta: 2.1324681450031326e-17  R2: -11.956827183913218
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch8
# tau: 180.46123698915662  beta: 2.1324681450031326e-17  R2: -11.956827183913218
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch6
# tau: 180.46123698915662  beta: 2.1324681450031326e-17  R2: -11.956827183913218
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch1
# tau: 180.46123698915662  beta: 2.1324681450031326e-17  R2: -11.956827183913218
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch10
# tau: 180.46113801075933  beta: 9.667019936529594e-19  R2: -23.748474481662967
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch11
# tau: 180.46113801075933  beta: 9.667019936529594e-19  R2: -23.748474481662967
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch9
# tau: 180.46113801075933  beta: 9.667019936529594e-19  R2: -23.748474481662967
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch7
# tau: 180.4613822928624  beta: 1.7185511023846603e-17  R2: -13.573200301940886
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch5
# tau: 180.4613822928624  beta: 1.7185511023846603e-17  R2: -13.573200301940886
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch12
# tau: 180.4611372675136  beta: 2.4278002854927885e-17  R2: -8.48544808611523
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch15
# tau: 180.4611372675136  beta: 2.4278002854927885e-17  R2: -8.48544808611523
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch13
# tau: 180.4610263055672  beta: 1.913853904400473e-17  R2: -6.718506402857524
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch16
# tau: 180.4613392672109  beta: 1.29665576213741e-16  R2: -6.721453127231316
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch14
# tau: 180.4613392672109  beta: 1.29665576213741e-16  R2: -6.721453127231316
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch17
# tau: 180.46103026208164  beta: 1.8088776949913177e-17  R2: -8.785641066604496
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch18
# tau: 180.46103026208164  beta: 1.8088776949913177e-17  R2: -8.785641066604496
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_FSSH_batch19
# tau: 180.46134962232313  beta: 5.0494858335856575e-17  R2: -11.202765060437885
# The timescales: nan+-nan average over 0 samples
# ------------IDA----------
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch0
# tau: 89.95072767792794  beta: 2.622915372691101e-11  R2: -3850.372353422131
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch1
# tau: 89.95071794885857  beta: 2.5701488486392493e-11  R2: -3330.8619148409975
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch5
# tau: 89.95067709937696  beta: 1.8897459827762244e-11  R2: -3511.8218698946353
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch2
# tau: 89.95067709937696  beta: 1.8897459827762244e-11  R2: -3511.8218698946353
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch3
# tau: 89.95069365862466  beta: 2.2611150571082747e-11  R2: -2452.5691484211693
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch4
# tau: 89.95065973021633  beta: 1.714283436951851e-11  R2: -23056.401146092518
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch7
# tau: 89.9507060928271  beta: 2.4794581975105064e-11  R2: -1267.737681442478
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch10
# tau: 89.9507060928271  beta: 2.4794581975105064e-11  R2: -1267.737681442478
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch8
# tau: 89.9507060928271  beta: 2.4794581975105064e-11  R2: -1267.737681442478
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch6
# tau: 89.9507060928271  beta: 2.4794581975105064e-11  R2: -1267.737681442478
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch11
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in double_scalars
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch13
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch9
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch14
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch12
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch17
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch15
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch16
# tau: 89.95069082833112  beta: 2.21486822768658e-11  R2: -1746.5274034488914
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch19
# tau: 89.95069082833112  beta: 2.21486822768658e-11  R2: -1746.5274034488914
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_IDA_batch18
# tau: 89.95069331636356  beta: 2.2291437040276358e-11  R2: -2452.3199013531616
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch3
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:195: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# tau: 180.46103026208164  beta: 1.8088776949913177e-17  R2: -8.785641066604496
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch4
# tau: 180.46134962232313  beta: 5.0494858335856575e-17  R2: -11.202765060437885
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch2
# tau: 180.4611909488987  beta: 3.104965324668608e-18  R2: -21.707300002024123
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch0
# tau: 180.4611909488987  beta: 3.104965324668608e-18  R2: -21.707300002024123
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch1
# tau: 907.4938347247264  beta: 1.0249534160608231  R2: 0.9412062165705336
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch6
# tau: 792.4368182046171  beta: 1.28589063454388  R2: 0.9823728643073611
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch5
# tau: 180.4611903411547  beta: 1.565661911831249e-16  R2: -5.249859212425728
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch7
# tau: 180.46089000075676  beta: 2.915320313965566e-18  R2: -9.270299769098491
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch8
# tau: 180.4610540461477  beta: 4.5845927103838086e-18  R2: -16.70159752484891
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch9
# tau: 180.46122244780133  beta: 9.845893442655001e-17  R2: -5.31601694674253
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch12
# tau: 180.46122244780133  beta: 9.845893442655001e-17  R2: -5.31601694674253
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch10
# tau: 180.461245150578  beta: 8.276563158515008e-17  R2: -6.133810658956806
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch17
# tau: 180.46126681584465  beta: 2.7092035812785006e-16  R2: -6.07078193367224
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch11
# tau: 180.46126681584465  beta: 2.7092035812785006e-16  R2: -6.07078193367224
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch13
# tau: 180.46126681584465  beta: 2.7092035812785006e-16  R2: -6.07078193367224
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch16
# tau: 180.46126681584465  beta: 2.7092035812785006e-16  R2: -6.07078193367224
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch14
# tau: 180.46074414852177  beta: 3.6482563102225177e-19  R2: -22.58039810597982
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch15
# tau: 180.46100351685163  beta: 2.2618267437382072e-18  R2: -19.70347592518906
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch18
# tau: 180.46100351685163  beta: 2.2618267437382072e-18  R2: -19.70347592518906
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_IDA_batch19
# tau: 837.0413246478543  beta: 1.2022403804083792  R2: 0.9605740525930799
# The timescales: nan+-53.59886995340898 average over 0 samples
# ------------mSDM----------
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch2
# tau: 89.95068409512686  beta: 2.1043643321306187e-11  R2: -2644.171923714951
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch1
# tau: 89.95067266308492  beta: 1.9060253710614987e-11  R2: -3511.8218698950127
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch5
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in double_scalars
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch3
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch0
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch10
# tau: 89.9506637541435  beta: 1.7972214097713594e-11  R2: -4384.549431958536
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch7
# tau: 89.95066060281778  beta: 1.7564248199897616e-11  R2: -9719.66139652636
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch4
# tau: 89.95066060281778  beta: 1.7564248199897616e-11  R2: -9719.66139652636
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch6
# tau: 89.95070131817917  beta: 2.382471242207181e-11  R2: -2541.6426869748675
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch8
# tau: 89.95070131817917  beta: 2.382471242207181e-11  R2: -2541.6426869748675
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch12
# tau: 89.95070131817917  beta: 2.382471242207181e-11  R2: -2541.6426869748675
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch9
# tau: 89.95066540821676  beta: 1.8084835104983834e-11  R2: -6358.609262822321
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch16
# tau: 89.95068318708745  beta: 2.0953661871636533e-11  R2: -2238.2541140684707
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch11
# tau: 89.95068318708745  beta: 2.0953661871636533e-11  R2: -2238.2541140684707
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch14
# tau: 89.95069826027093  beta: 2.3347059027278676e-11  R2: -2480.3522961246267
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch13
# tau: 89.95069826027093  beta: 2.3347059027278676e-11  R2: -2480.3522961246267
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch17
# tau: 89.95067158511648  beta: 1.879192194589562e-11  R2: -2983.0995806675423
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch19
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch15
# tau: 89.95065553416565  beta: 1.6928475753838842e-11  R2: -inf
# Folder = ./results/namd_regular_hole_only_sd/_start_s10_mSDM_batch18
# tau: 89.95074218871623  beta: 3.2312275201325593e-11  R2: -677.8910063772616
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch3
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:195: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/98722002/miniconda3/envs/libra/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# tau: 837.0413246478543  beta: 1.2022403804083792  R2: 0.9605740525930799
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch4
# tau: 180.4610036996258  beta: 1.6137299066222975e-18  R2: -19.56738662790674
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch0
# tau: 180.4610036996258  beta: 1.6137299066222975e-18  R2: -19.56738662790674
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch1
# tau: 180.4610036996258  beta: 1.6137299066222975e-18  R2: -19.56738662790674
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch8
# tau: 180.46121871493307  beta: 3.4103122235525045e-17  R2: -10.957229949933392
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch5
# tau: 180.46121871493307  beta: 3.4103122235525045e-17  R2: -10.957229949933392
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch6
# tau: 180.46124494035496  beta: 5.34976910499078e-18  R2: -17.69815566354617
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch2
# tau: 180.46124494035496  beta: 5.34976910499078e-18  R2: -17.69815566354617
# Folder = ./results//namd_regular_electron_only_sd/_start_s10_mSDM_batch11
